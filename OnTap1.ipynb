# %% [markdown]
# ### 1. Yêu cầu: Cước phí Taxi Thông Minh.
# Viết một hàm duy nhất smart_taxi_fare(car_type, start_hour, km, wait_minutes) tính và trả về total (tổng tiền phải trả,
# kiểu số nguyên, đơn vị VND).
# Các quy tắc cần cài đặt:
# 1. Giá mở cửa (0–0.8 km):
# - Xe 4 chỗ: 11,000 VND
# - Xe 7 chỗ: 12,000 VND
# 2. Giá theo km sau 0.8 km:
# - Xe 4 chỗ: từ 0.8→20 km ơnh 13,000 VND/km; trên 20 km tính 10,500 VND/km
# - Xe 7 chỗ: từ 0.8→20 km ơnh 14,000 VND/km; trên 20 km tính 12,000 VND/km
# 3. Phí chờ: 5 phút đầu miễn phí; sau đó, mỗi 5 phút (làm tròn lên theo từng block 5 phút) tính 2,000 VND.
# 4. Phụ thu ban đêm: nếu start_hour thuộc [22,23,0,1,2,3,4,5], cộng +20% trên tiền tạm tính (mở cửa + quãng đường +
# chờ).
# 5. Điều kiện đặc biệt:
# - Nếu km > 30 và không phải ban đêm, áp dụng giảm 10% trên tổng tiền.
# - Nếu tổng tiền cuối cùng < 50,000 nhưng km > 5, đặt tổng tiền bằng 50,000 VND (mức tối thiểu).

# %%
def smart_taxi_fare(car_type, start_hour, km, wait_minutes):
    if car_type==4:
        if km<=0.8:
            gia_xe=11000
        elif 0.8<km<=20:
            gia_xe=11000+(km-0.8)*13000
        else:
            gia_xe=11000+(20-0.8)*13000+(km-20)*10500
    if car_type==7:
        if km<=0.8:
            gia_xe=12000
        elif 0.8<km<=20:
            gia_xe=12000+(km-0.8)*14000
        else:
            gia_xe=12000+(20-0.8)*14000+(km-20)*12000
    if wait_minutes<=5:
        phi_cho=0
    elif wait_minutes>5:
        phi_cho=((wait_minutes-5)//5+1)*2000
    total=gia_xe + phi_cho
    if start_hour in [22,23,0,1,2,3,4,5]:
        total=1.2*(gia_xe+phi_cho)
    else:
        if km > 30: 
            total*=0.9
    if total < 50000 and km > 5:
        total=50000  
    return total
car_type,start_hour,km,wait_minutes=map(float,input().split())
results=smart_taxi_fare(car_type, start_hour, km, wait_minutes)
print(int(results))
# Out:
# 168960

# %% [markdown]
# ### 2.Yêu cầu: Cho số nguyên x, trả về True nếu tồn tại số nguyên n ≥ 1 sao cho x = 1 + 2 + ... + n, ngược lại trả về False.
# Khuyến khích dùng vòng lặp đơn giản để cộng dồn tổng.

# %%
x=int(input())
tong=0
for i in range(1,x+1):
    tong+=i
    if tong == x:
        print("True")
        break
else:
    print("False")
# Out:
# True

# %% [markdown]
# ### 3 Yêu cầu: Cho tọa độ ba điểm A(x1,y1), B(x2,y2), C(x3,y3), trả về True nếu chúng tạo thành một tam giác, ngược lại trả về
# False.
# Quy tắc: Chúng tạo thành tam giác nếu không thẳng hàng (diện tích có hướng khác 0).

# %%
x1, y1 =map(int,input("A").split())
x2, y2 =map(int,input("B").split())
x3, y3 =map(int,input("C").split())
c=((x2-x1)**2+(y2-y1)**2)**0.5
a=((x3-x2)**2+(y3-y2)**2)**0.5
b=((x3-x1)**2+(y3-y1)**2)**0.5
p=(a+b+c)/2
S2=p*(p-a)*(p-b)*(p-c)
if S2==0:
    print("False")
else:
    print("True")
# Out:
# True

# %%
x1, y1 =map(int,input("A").split())
x2, y2 =map(int,input("B").split())
x3, y3 =map(int,input("C").split())
c=((x2-x1)**2+(y2-y1)**2)**0.5
a=((x3-x2)**2+(y3-y2)**2)**0.5
b=((x3-x1)**2+(y3-y1)**2)**0.5
if a+b>c and a+c>b and c+b>a:
    print("True")
else: 
    print("False")

# %%
x1, y1 =map(int,input("A").split())
x2, y2 =map(int,input("B").split())
x3, y3 =map(int,input("C").split())
S=0.5 * ( x1 * (y2-y3) + x2 * (y3-y1) + x3 * (y1-y2))
if S != 0 :
    print("True")
else:
    print("False")

# %% [markdown]
# ### 4 Yêu cầu: Cho các hệ số thực a, b, c, trả về tất cả các nghiệm thực của phương trình bậc hai axx + bx + c = 0 trong một danh sách được sắp xếp tăng dần.
# Quy tắc:
# - Nếu a == 0 và b != 0: trả về nghiệm duy nhất [-c / b].
# - Nếu a == 0 và b == 0: trả về [] (không có nghiệm hữu hạn duy nhất nếu c == 0, hoặc vô nghiệm nếu c != 0).
# - Với a != 0, dùng biệt thức d = bb - 4ac:
# - d < 0 → []
# - d == 0 → [ -b / (2a) ]
# - d > 0 → hai nghiệm [r1, r2] với r1 <= r2

# %%
a, b, c= map(float,input().split())
nghiem=[]
if a==0 and b != 0:
    x = -c/b
    nghiem.append(x)
elif a != 0:
    d = b*b - 4*a*c
    if d == 0 :
        x = -b/(2*a)
    elif d > 0:
        r1 = ( -b - d**0.5)/(2*a)
        r2 = ( -b + d**0.5)/(2*a)  
        nghiem.append(round(r1,2))
        nghiem.append(round(r2,2))
print(nghiem)
# Out:
# []

# %% [markdown]
# ### 5. Yêu cầu: Cho ba số a, b, c, trả về chúng dưới dạng danh sách theo thứ tự không giảm.

# %%
a = list(map(float,input().split()))
a.sort(reverse=False)
print(a)
# Out:
# [0.0, 1.0, 1.0, 2.0, 3.0, 3.0, 3.0, 3.0, 5.0, 6.0, 6.0, 7.0, 7.0, 8.0, 10.0, 15.0]

# %%
a=[]
while True:
    n=input()
    if n=='x':
        break
    b = float(n)
    a.append(b)
def sap_xep(a):
    m=len(a)
    for i in range(m):
        for j in range(i+1,m):
            if a[i]>a[j]:
                a[i],a[j]=a[j],a[i]
    return a
print(sap_xep(a))
# Out:
# [2.0, 4.0, 6.0, 7.0, 9.0]

# %% [markdown]
# ### 6. Yêu cầu: Cho năm số a, b, c, d, e, trả về True nếu tồn tại bất kỳ ba số nào trong đó bằng nhau; ngược lại trả về False.
# Không dùng tuple hay dictionary.

# %%
a=list(map(int,input().split()))
b=sap_xep(a)
k=int(input())
def kiem_tra_trung_nhau_k_lan(b,k):
    m=len(b)
    for i in range(m-k+1):  #để đủ k phần tử sau i
        if b[i]==b[i+(k-1)]:
            return True
    return False
print(kiem_tra_trung_nhau_k_lan(b,k))
# Out:
# False

# %%
def kiem_tra_trung_lap(a,k):
    da_xet=[]
    n=len(a)
    for i in range(n):
        so_dang_xet=a[i]
        da_dem_chua = False
        for da_check in da_xet :
            if so_dang_xet == da_check:
                da_dem_chua = True
                break
        if da_dem_chua == True:   #if da_dem_chua:   cũng tương tự
            continue
        dem=0
        for j in range(n):
            if a[j]== so_dang_xet:
                dem+=1
        if dem >= k:
            return True
        da_xet.append(so_dang_xet)
    return False
a=list(map(int, input().split()))
k=int(input())

# %% [markdown]
# ### 7 Yêu cầu: Cho ba số a, b, c, trả về giá trị ở giữa khi sắp xếp ba số theo thứ tự tăng dần (giá trị lớn thứ hai).
# Định nghĩa này vẫn đúng khi có phần tử trùng nhau (ví dụ: 2, 2, 5 → giá trị giữa là 2)

# %%
m=list(map(int,input().split()))
n=sap_xep(m)
print(m[1])
# Out:
# 5

# %%
def tim_gia_tri_o_giua_tong_quat(danh_sach):
    # Bước 1: Sắp xếp
    b = sap_xep(danh_sach) 
    n = len(b)
    
    mid = n // 2
    
    if n % 2 != 0:
        # Số lẻ: Trả về số chính giữa
        return b[mid]
    else:
        # Số chẵn: Trả về trung bình cộng 2 số giữa
        return (b[mid - 1] + b[mid]) / 2
danh_sach=list(map(int,input().split()))
print(tim_gia_tri_o_giua_tong_quat(danh_sach))

# %% [markdown]
# ### 8.Yêu cầu: Cho hai ngày sinh dưới dạng (day, month, year) của người 1 và người 2, trả về 1 nếu người 1 lớn tuổi hơn (ngày sinh sớm hơn), 2 nếu người 2 lớn tuổi hơn, và 0 nếu bằng nhau.
# Ví dụ: 27 2 2007 so với 28 2 2007 → trả về 1 vì ngày 27 sớm hơn nên người 1 lớn tuổi hơn.

# %%
day1, month1, year1 =map(int,input().split())
day2, month2, year2 =map(int,input().split())
def so_sanh_tuoi(day1, month1, year1,day2, month2, year2):
    if year1 < year2:
        return 1
    elif year2 < year1:
        return 2
    else:
        if month1 < month2:
            return 1
        elif month2 < month1:
            return 2
        else:
            if day1 < day2:
                return 1
            elif day2 < day1:
                return 2
            else:
                return 0
print(so_sanh_tuoi(day1, month1, year1,day2, month2, year2))

# %%
day1, month1, year1 =map(int,input().split())
day2, month2, year2 =map(int,input().split())
gia_tri1=year1*10000+month1*100+day1
gia_tri2=year2*10000+month2*100+day2
if gia_tri1 < gia_tri2: 
    print(1)
if gia_tri1 > gia_tri2: 
    print(2)
else : 
    print(0)

# %% [markdown]
# ### 9.Yêu cầu: Cho số nguyên n, trả về:
# - 5n + 1 nếu n mod 3 == 1
# - 6n + 2 nếu n mod 3 == 2
# - 7n + 3 nếu n mod 3 == 0

# %%
n=int(input())
if n%3==1:
    print(5*n+1)
elif n%3==2:
    print(6*n+2)
else:
    print(7*n+3)
# Out:
# 45

# %% [markdown]
# ### 10.Yêu cầu: Cho điểm số s, trả về xếp loại chữ theo quy tắc:
# - A+ nếu s ≥ 9
# - A nếu s ≥ 8.5
# - B+ nếu s ≥ 8
# - B nếu s ≥ 7
# - E nếu còn lại

# %%
s= float(input())
if s>=9:
    print("A+")
elif 8.5<=s<9:
    print("A")
elif 8<=s<8.5:
    print("B+")
elif 7<=s<8:
    print("B")
else:
    print("E")

# %% [markdown]
# ### 11.Yêu cầu: Cho một chuỗi giới tính và chiều cao tính bằng mét, trả về True nếu người đó là nam và cao hơn 1.70 m; ngược lại trả về False.
# Chấp nhận các cách biểu diễn nam như 'male', 'm', 'nam' (không phân biệt hoa thường).

# %%
gioi_tinh=input()
chieu_cao=float(input())
a=gioi_tinh.lower()
if chieu_cao > 1.7 and gioi_tinh in ["male","m","nam"]:
    print("True")
else:
    print("False")
# Out:
# True

# %% [markdown]
# ### 12 Yêu cầu: Cho cân nặng (kg) và chiều cao (m) của hai người, hãy trả về người có BMI cao hơn.
# Trả về 1 nếu người 1 có BMI cao hơn, 2 nếu người 2 có BMI cao hơn, và 0 nếu bằng nhau.
# Nhắc lại: BMI = weight / (height height).

# %%
def tinh_bmi(kg,m):
    bmi=kg/m
    return bmi
kg1, m1= map(float,input().split())
kg2, m2= map(float,input().split())
if tinh_bmi(kg1,m1) > tinh_bmi(kg2,m2):
    print(1)
if tinh_bmi(kg1,m1) < tinh_bmi(kg2,m2):
    print(2)
else:
    print(0)
# Out:
# 2

# %% [markdown]
# ### 13.Viết hàm trả về tổng bình phương các số từ 1 đến n.

# %%
tong=0
n=int(input())
for i in range(1,n+1):
    tong+=i**2
print(tong)
# Out:
# 91

# %% [markdown]
# ### 14.Viết hàm trả về hệ số nhị thức C(n, k)
