# %% [markdown]
# ### W9A1
# Viết hàm merge hai danh sách đã sắp xếp mà không dùng bất cứ thuật toán sắp xếp nào

# %%
def merge_2_dsach(list1,list2):
    ket_qua = []
    i = 0
    j = 0
    while i < len(list1) and j < len(list2):
        if list1[i] < list2[j]:
            ket_qua.append(list1[i])
            i += 1
        else:
            ket_qua.append(list2[j])
            j += 1
    ket_qua.extend(list1[i:])
    ket_qua.extend(list2[j:])
    return ket_qua
list1 = list(map(int,input().split()))
list2 = list(map(int,input().split()))
print(merge_2_dsach(list1,list2))

# %% [markdown]
# ### W9A2
# Cho ma trận hai chiều nxm có các phần tử được sắp xếp trên
# dòng tăng dần và trên cột tăng dần, hãy tìm số nhỏ thứ k (k <
# nxm) với thuật toán tốt nhất có thể

# %%
def dem_phan_tu(matrix,mid,n,m):
    count = 0
    row = n-1
    col = 0
    while row >= 0 and col < m:
        if matrix[row][col] <= mid:
            count += (row + 1) #cộng tất cả bên trên
            col += 1 # tiến sang phải
        else:
            row -= 1  #lùi lên
    return count
def tim_so_nho_thu_k(matrix,k,n,m):
    low = matrix[0][0]
    high = matrix[n-1][m-1]
    ans = low
    while low <= high:
        mid = (low + high) // 2
        if dem_phan_tu(matrix,mid,n,m) >= k:
            ans = mid
            high = mid - 1
        else:
            low = mid + 1
    return ans
n, m, k = map(int, input().split())
matrix = []
for i in range(n):
    row = list(map(int, input().split()))
    matrix.append(row)
print(tim_so_nho_thu_k(matrix,k,n,m))
# Out:
# 6

# %% [markdown]
# ### W9A3
# Cho một số nguyên dương, hãy thực hiện hoán đổi đúng 2 chữ
# số để được một số nguyên nhỏ nhất có thể

# %%
def doi_2_chu_so(so):
    N = list(so.strip())
    n = len(N)
    for i in range(n-1):
        vtri_min = i
        for j in range(n-1,i,-1):
            if N[j] < N[vtri_min] or vtri_min == i:
                vtri_min = j
        if vtri_min != i:
            N[i], N[vtri_min] = N[vtri_min], N[i]
            return "".join(N)
    N[-1], N[-2] = N[-2], N[-1]
    return "".join(N)
so = str(input())
print(doi_2_chu_so(so))
# Out:
# 1222229999992323211112

# %% [markdown]
# ### W9A4
# Cho xâu a gồm các chữ cái thường và in hoa và xâu b chỉ gồm
# các chữ cái in hoa. Ta có thể biến đổi xâu a theo 2 bước như sau:
# - Chuyển một số chữ cái thường trong xâu a thành chữ cái in hoa
# (có thể không biến đổi chữ cái nào)
# - Xóa hết tất cả các chữ cái thường trong xâu a.
# ###### Cho 2 xâu a,b, xác đính xem có cách biến đổi từ xâu a sang xâu b không. Ghi ra "YES" nếu có và "NO" nếu ngược lại.
# ###### Đầu vào:
# Dòng đầu tiên chứa 1 số nguyên Q là số lượng câu hỏi. Tương
# ứng với mỗi câu hỏi, đưa ra 2 xâu a,b trên 2 dòng khác
# nhau.(Q≤10,|a|,|b|≤1000
# )
# ###### Đầu ra:
# Với mỗi câu hỏi, ghi ra kết quả tương ứng trên một dòng.

# %%
# vòng lặp while
def kiem_tra_bien_doi(a,b):
    i = 0
    j = 0
    while i < len(a) and j < len(b):
        if a[i].isupper():
            if a[i] == b[j]:
                i += 1
                j += 1
            else:
                return "NO"
        else:
            if a[i].upper() == b[j]:
                i += 1
                j += 1
            else:
                i += 1
    # đảm bảo không còn chữ hoa thừa nào ở a sau khi xét
    while i < len(a):
        if a[i].isupper():
            return "NO"
        i += 1
    # Và phải khớp hết toàn bộ xâu b
    if j == len(b):
        return "YES" 
    else:
        return "NO"
Q = int(input())
cau_hoi = []
for _ in range(Q):
    a = input()
    b = input()
    print(kiem_tra_bien_doi(a,b))
# Out:
# YES
# NO

# %%
# đệ quy
def check_bien_doi(a,b, i=0, j=0):
    if j == len(b):  #điểm dừng 1
        for vtri in range(i,len(a)):
            if a[vtri].isupper():
                return "No"
        return "Yes"
    if i == len(a):  #điểm dừng 2
        return "No"
    if a[i].isupper():
        if a[i] == b[j]:
            return check_bien_doi(a,b,i+1,j+1)
        else:
            return "No"
    else:
        xoa_chu = check_bien_doi(a,b,i+1,j)
        in_hoa = "No"
        if a[i].upper() == b[j]:
            in_hoa = check_bien_doi(a,b,i+1,j+1)
        return xoa_chu or in_hoa
Q = int(input())
cau_hoi = []
for _ in range(Q):
    a = input()
    b = input()
    print(kiem_tra_bien_doi(a,b))
# Out:
# YES
# NO

# %% [markdown]
# ### W9A5
# Cho hai mảng số nguyên list1 và list2, viết hàm kiểm tra xem list1
# có thuộc list2 hay không (có phải là dãy con liên tiếp của list2 hay
# không)?

# %%
def kiem_tra_day_con(list1,list2):
    if not list1:   #dãy rỗng luôn là dãy con
        return "Yes"
    i = 0
    j = 0
    while j < len(list2):
        if list1[i] == list2[j]:
            i += 1
            j += 1
            if i == len(list1):
                return "Yes"
        else:
            j = j - i +1   
            #lùi j về ngay sau vị trí bắt đầu của chuỗi khớp vừa rồi
            i = 0
    return "No"   
list1 = list(map(int,input().split()))
list2 = list(map(int,input().split()))
print(kiem_tra_day_con(list1,list2))
# Out:
# Yes

# %% [markdown]
# ### W9A6
# [Hoán vị tiếp theo]
# Cho một dãy số gồm n chữ số là một hoán vị của dãy 1,2,...,n.
# Viết chương trình in ra hoán vị ở vị trí tiếp theo (danh sách các
# hoán vị được sắp xếp theo thứ tự từ điển) của hoán vị đã cho.
# Đầu vào từ bàn phím gồm 2 dòng:
# - Dòng đầu tiên chứa số nguyên n
# - Dòng tiếp theo chứa n số nguyên là một hoán vị của dãy 1,2,...,n
# (n≤105)
# ##### Đầu ra: In ra màn hình hoán vị tiếp theo của hoán vị đã cho.

# %%
def hoan_vi_tiep_theo(hoan_vi):
    n = len(hoan_vi)
    i = n - 2
    while i >= 0 and hoan_vi[i] >= hoan_vi[i+1]:
        i -= 1
    if i == -1:
        hoan_vi.reverse()
        return hoan_vi
    j = n - 1
    while j >= 0 and hoan_vi[j] <= hoan_vi[i]:
        j -= 1
    hoan_vi[j], hoan_vi[i] = hoan_vi[i], hoan_vi[j]
    hoan_vi[(i+1) :] = reversed(hoan_vi[(i+1) :])
    return hoan_vi
n = int(input())
hoan_vi = list(map(int,input().split()))
ket_qua=hoan_vi_tiep_theo(hoan_vi)
print(*ket_qua)
# Out:
# 4 6 1 2 3 5

# %% [markdown]
# ### W9A7
# [CanPlaceFlowers]
# Viết hàm canPlaceFlowers(flowerbed, k) kiểm tra xem có thể
# trồng hết số hoa mới được cấp vào trong luống đất của bạn hay
# không.
# Hàm nhận đầu vào là một danh sách (list) flowerbed, đánh dấu
# những vị trí trong luống đất đã được trồng cây xanh trước đó (giá
# trị 1 ứng với vị trí cây đã được trồng và 0 ứng với vị trí đất trống)
# và số lượng hoa được phát thêm k (int). Hàm trả về True nếu có
# thể trồng hết toàn bộ k cây hoa vào luống đất và False trong
# trường hợp ngược lại

# %%
def canPlaceFlowers(flowerbed, k):
    if k == 0:
        return True
    n = len(flowerbed)
    for o in range(n):
        if flowerbed[o] == 0:
            trai_trong = (o == 0) or (flowerbed[o-1] == 0) 
            phai_trong = (o == n-1) or (flowerbed[o+1] == 0) 
            if trai_trong and phai_trong:
                k -= 1
                flowerbed[o] = 1 #quan trọng
            if k <= 0:
                return True
    return False
flowerbed = list(map(int,input().split()))
k = int(input())
print(canPlaceFlowers(flowerbed, k))
# Out:
# True

# %% [markdown]
# ### W9A8
# [Phát hiện đường đi lặp lại của Rô-bốt]
# Ban đầu, một con rô-bốt ở vị trí (0, 0) trên một lưới 2D.
# Cho một chuỗi `moves` chứa các thao tác di chuyển của rô-bốt.
# Các bước di chuyển được biểu diễn bởi các ký tự:
# - 'R' (Phải)
# - 'L' (Trái)
# - 'U' (Lên)
# - 'D' (Xuống)
# + Viết hàm `def is_path_crossing(moves)`:
# + Hàm nhận đầu vào là một chuỗi `moves`.
# + Hàm trả về `True` nếu trong quá trình di chuyển, rô-bốt đi vào một ô mà nó đã từng đi qua trước đó.
# + Hàm trả về `False` nếu rô-bốt không bao giờ đi lặp lại (luôn đi vào ô mới).
# + Lưu ý: Vị trí ban đầu (0, 0) được tính là vị trí đầu tiên đã đi qua.

# %%
def is_path_crossing(moves):
    da_di_qua = {(0,0)}
    x = 0
    y = 0
    for buoc in moves:
        if buoc == "R":
            x += 1
        elif buoc == "L":
            x -= 1
        elif buoc == "U":
            y += 1
        elif buoc == "D":
            y -= 1
        if (x,y) in da_di_qua:
            return True
        da_di_qua.add((x,y))
    return False
moves = input().strip()
print(is_path_crossing(moves))
# Out:
# True

# %% [markdown]
# ### W9A9
# [HARD - Tìm trung vị của 5 số]
# Viết hàm `def Median(nums):`
# Hàm nhận đầu vào là một danh sách (list) `nums` được đảm bảo
# có đúng 5 số nguyên.
# Yêu cầu:
# Tìm và trả về số trung vị (số lớn thứ ba) của 5 số này.
# Ràng buộc:
# 1. Chỉ được sử dụng tối đa 6 phép so sánh (ví dụ: <, >, <=, >=).
# 2. KHÔNG ĐƯỢC DÙNG bất kỳ hàm sắp xếp nào (như
# `sorted()`, `list.sort()`).
# Chú ý: Bạn chỉ cần viết hàm `Median` theo yêu cầu.
# Phần đọc input và gọi hàm (hàm main) đã có sẵn.

# %%
def Median(nums):
    a,b,c,d,e=nums
    def doi_cho(x,y):
        if x > y:
            return (y,x)
        else:
            return (x,y)
    a,b = doi_cho(a,b)  #đảm bảo a < b
    c,d = doi_cho(c,d)  #đảm bảo c < d
    if b > d:
        a,b,c,d = c,d,a,b  #để b < d
    #'d' lớn hơn ít nhất 3 số (a, b, c) -> d không phải trung vị.
    #'a' nhỏ hơn ít nhất 2 số (b, d) -> a không phải trung vị.
    c,e = doi_cho(c,e)  #đảm bảo c < e
    if b < c:  #số nhỏ nhất là b -> bị loại
        return c #c < e -> b<c<e -> c là trung vị
    else:   #số nhỏ nhất là c -> bị loại
        if b < e:
            return b
        else:
            return e
nums = list(map(int,input().split()))
print(Median(nums))
# Out:
# 5

# %% [markdown]
# ### W9A10
# [Tìm bán kính lò sưởi nhỏ nhất]
# Mùa đông đang đến! Bạn được cung cấp vị trí của các ngôi nhà
# và các lò sưởi trên một đường thẳng.
# Nhiệm vụ của bạn là tìm bán kính r nhỏ nhất cho các lò sưởi sao
# cho mọi ngôi nhà đều nằm trong phạm vi sưởi ấm của ít nhất một
# lò sưởi.
# Tất cả các lò sưởi đều có cùng một bán kính r.
# + Một ngôi nhà tại vị trí h được sưởi ấm bởi một lò sưởi tại vị trí t nếu |h - t| <= r.
# + Viết hàm `def findRadius(houses, heaters):`
# + Hàm nhận đầu vào là hai danh sách (list) các số nguyên:
# - `houses`: chứa vị trí của các ngôi nhà.
# - `heaters`: chứa vị trí của các lò sưởi.
# + Hàm trả về một số nguyên là bán kính r nhỏ nhất cần thiết.
# + Lưu ý:
# - Số lượng nhà và lò sưởi là một số không âm và không vượt quá
# 25000.
# - Vị trí của các ngôi nhà và lò sưởi là một số không âm và không
# vượt quá 10^9.

# %%
def findRadius(houses, heaters):
    
houses = list(map(int, input().split()))
heaters = list(map(int, input().split()))
print(findRadius(houses, heaters))

# %% [markdown]
# #### W9A11
# Viết hàm factorial(n) tính giai thừa của n bằng đệ quy.

# %%
def factorial(n):
    if n == 0 or n == 1:
        return 1
    return n*factorial(n-1)
n = int(input())
print(factorial(n))
# Out:
# 120

# %% [markdown]
# #### W9A12
# Viết hàm sum_to_n(n) tính tổng từ 1 đến n bằng đệ quy.

# %%
def sum_to_n(n):
    if n == 1:
        return 1
    return n + sum_to_n(n - 1)
n = int(input())
print(sum_to_n(n))
# Out:
# 1275

# %% [markdown]
# #### W9A13
# Viết hàm power(base, exp) tính base^exp bằng đệ quy chia để trị.
# Yêu cầu:
# - Không dùng vòng lặp
# - Không dùng hàm có sẵn

# %%
def power(base, exp):
    if exp == 0:
        return 1
    half = power(base, exp // 2)
    if exp % 2 == 0:
        return half * half
    else:
        return half * half * base
base, exp = map(int,input().split())
print(power(base, exp))
# Out:
# 279936

# %% [markdown]
# #### W9A14
# VIế́t hàm tìm số xuất hiện nhiều hơn x lần trong một dãy số (x là số nguyên dương nhập
# từ bàn phím). Nếu không có số nào thì in ra "INVALID"

# %%
def find_frequent_numbers():
    try:
        nums = list(map(int, input().split()))
        x = int(input())
        counts = {}
        for num in nums:
            counts[num] = counts.get(num, 0) + 1
        result = [num for num, count in counts.items() if count > x]
        if not result:
            print("INVALID")
        else:
            print(*(result))
    except ValueError:
        print("Vui lòng nhập số nguyên hợp lệ.")
find_frequent_numbers()
# Out:
# 2

# %% [markdown]
# #### W9A15
# VIết hàm kiểm tra dãy số nguyên vào từ bàn phím có phải dãy tăng nghiêm ngặt (giảm
# nghiêm ngặt) hay không?

# %%
def check_sequence():
    try:
        arr = list(map(int, input("Nhập dãy số: ").split()))
        if len(arr) < 2:
            print("Dãy phải có ít nhất 2 phần tử.")
            return

        is_increasing = all(arr[i] < arr[i+1] for i in range(len(arr) - 1))
        is_decreasing = all(arr[i] > arr[i+1] for i in range(len(arr) - 1))

        if is_increasing:
            print("Dãy tăng nghiêm ngặt")
        elif is_decreasing:
            print("Dãy giảm nghiêm ngặt")
        else:
            print("Không phải dãy tăng hay giảm nghiêm ngặt")
    except ValueError:
        print("Dữ liệu nhập vào không hợp lệ.")
check_sequence()
# Out:
# Dãy tăng nghiêm ngặt
